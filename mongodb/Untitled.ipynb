# %%
def get_database():
    from pymongo import MongoClient
    import pymongo

    # Provide the mongodb atlas url to connect python to mongodb using pymongo
    CONNECTION_STRING = "mongodb+srv://m001-student:m001-mongodb-basics@sandbox.dvv4g.mongodb.net/test?authSource=admin&replicaSet=atlas-6qg4gc-shard-0&readPreference=primary&ssl=true"

    # Create a connection using MongoClient. You can import MongoClient or use pymongo.MongoClient
    from pymongo import MongoClient
    client = MongoClient(CONNECTION_STRING)

    # Create the database for our example (we will use the same database throughout the tutorial
    return client['user_shopping_list']

# %%
# Get the database using the method we defined in pymongo_test_insert file
import pandas as pd
from pymongo_test_insert import get_database
dbname = get_database()

# Create a new collection
collection_name = dbname["user_1_items"]

item_details = collection_name.find()

items_df = pd.DataFrame(item_details)
items_df
# Out:
#                         _id      item_name           category  quantity  \
# 0                 U1IT00002            Egg               food      12.0
# 1                 U1IT00001        Blender  kitchen appliance       NaN
# 2  630f992ff2ba712f3087009e          Bread                NaN       2.0
# 3  630f9ba2952dc5fe932a1400  Medias Noches                NaN       2.0
# 4                 U1IT00012    Corn Flakes             Cereal       NaN
# 5                 U1IT00022        Cookies               food      12.0
#
#    price    item_description max_discount batch_number        ingredients  \
# 0   36.0  brown country eggs          NaN          NaN                NaN
# 1  340.0                 NaN          10%  RR450020FRG                NaN
# 2    NaN                 NaN          NaN          NaN  all-purpose flour
# 3    NaN                 NaN          NaN          NaN  all-purpose flour
# 4  140.0                 NaN          10%  RR450020FLG                NaN
# 5   35.0         Box Cookies          NaN          NaN                NaN
#
#   expiry_date
# 0         NaT
# 1         NaT
# 2  2021-07-13
# 3  2021-08-13
# 4         NaT
# 5         NaT

# %%
item_1 = {
"_id" : "U1IT00012",
"item_name" : "Corn Flakes",
"max_discount" : "10%",
"batch_number" : "RR450020FLG",
"price" : 140,
"category" : "Cereal"
}

item_2 = {
"_id" : "U1IT00022",
"item_name" : "Cookies",
"category" : "food",
"quantity" : 12,
"price" : 35,
"item_description" : "Box Cookies"
}
collection_name.insert_many([item_1,item_2])
